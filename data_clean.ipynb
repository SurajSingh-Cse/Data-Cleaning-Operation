# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df=pd.read_csv("suraj.csv")
df
# Out:
#     Index  Organization Id                         Name  \
# 0       1  E84A904909dF528                not available
# 1       2              NaN                not available
# 2       3              NaN                    Gill-Lamb
# 3       4  D76BB12E5eE165B                  Bauer-Weiss
# 4       5  2F31EddF2Db9aAE                  Love-Palmer
# 5       6  6774DC1dB00BD11  Farmer, Edwards and Andrade
# 6       7  116B5cD4eE1fAAc     Bass, Hester and Mcclain
# 7       8  AB2eA15d98b6BD4  Strickland, Gray and Jensen
# 8       9              NaN    Sparks, Decker and Powell
# 9      10              NaN   Osborn, Ford and Macdonald
# 10     11  C494aBe0CDB9c70                not available
# 11     12  9FBF69aa2D9AAF1                not available
# 12     13  4EB9d3E5cF79b91   Bernard, Payne and Spencer
# 13     14  e5CA6529DCD4030          Mcpherson-Blanchard
# 14     15  b0BBeBB36bAbb35         Koch, Gomez and Hays
# 15     16  CDa7Ec784D5A8Bd      Meza, Ramirez and Braun
# ...

# %%
df.shape
# Out:
# (20, 10)

# %%
df.isnull().sum()
# Out:
# Index                   0
# Organization Id         4
# Name                    0
# Website                 5
# Country                 0
# Description            10
# Founded                 2
# Industry                0
# Number of employees     0
# Unnamed: 9             20
# dtype: int64

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.drop(columns=["Description"],inplace=True) #delete "description" column from csv file

# %%
df.isnull().sum()
# Out:
# Index                   0
# Organization Id         4
# Name                    0
# Website                 5
# Country                 0
# Founded                 2
# Industry                0
# Number of employees     0
# Unnamed: 9             20
# dtype: int64

# %%
df.dropna()  #it is remove column which is present missing value
# Out:
# Empty DataFrame
# Columns: [Index, Organization Id, Name, Website, Country, Founded, Industry, Number of employees, Unnamed: 9]
# Index: []

# %%
df.dropna(inplace=True)  #it is remove all missing value

# %%
df.isnull().sum()
# Out:
# Index                  0
# Organization Id        0
# Name                   0
# Website                0
# Country                0
# Founded                0
# Industry               0
# Number of employees    0
# Unnamed: 9             0
# dtype: int64

# %%
df.shape
# Out:
# (0, 9)
